# %%
import pandas as pd

# %%
# load dataset from data/universal_top_spotify_songs.csv (https://www.kaggle.com/datasets/asaniczka/top-spotify-songs-in-73-countries-daily-updated)
df = pd.read_csv('raw_data/universal_top_spotify_songs.csv')
df.head()
# Out:
#                spotify_id                name                artists  \
# 0  2RkZ5LkEzeHGRsmDqKwmaJ            Ordinary            Alex Warren
# 1  42UBPzRMh5yyz0EDPr6fr1            Manchild      Sabrina Carpenter
# 2  0FTmksd2dxiE5e3rWyJXs6     back to friends                  sombr
# 3  7so0lgd0zP2Sbgs2d7a1SZ    Die With A Smile  Lady Gaga, Bruno Mars
# 4  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER          Billie Eilish
#
#    daily_rank  daily_movement  weekly_movement country snapshot_date  \
# 0           1               1                0     NaN    2025-06-11
# 1           2              -1               48     NaN    2025-06-11
# 2           3               0                1     NaN    2025-06-11
# 3           4               0               -1     NaN    2025-06-11
# 4           5               1                0     NaN    2025-06-11
#
#    popularity  is_explicit  ...  key loudness mode  speechiness  acousticness  \
# ...

# %%
# from col snapshot_date, get rows with snapshot_date equal to 2025-06-11 only
df = df[df['snapshot_date'] == '2025-06-11']
df.shape
# Out:
# (3600, 25)

# %%
df.head(20)
# Out:
#                 spotify_id                                     name  \
# 0   2RkZ5LkEzeHGRsmDqKwmaJ                                 Ordinary
# 1   42UBPzRMh5yyz0EDPr6fr1                                 Manchild
# 2   0FTmksd2dxiE5e3rWyJXs6                          back to friends
# 3   7so0lgd0zP2Sbgs2d7a1SZ                         Die With A Smile
# 4   6dOtVTDdiauQNBQEDOtlAB                       BIRDS OF A FEATHER
# 5   27xkOIER6uDLKALIelHylZ                    Don’t Say You Love Me
# 6   6iOndD4OFo7GkaDypWQIou                    La Plena - W Sound 05
# 7   4AajxCEwGEsmHmT4H1TwjY                                undressed
# 8   4wJ5Qq0jBN4ajy7ouZIV1c                                     APT.
# 9   4WFgvKVfEhb3IUAFGrutTR                              Love Me Not
# 10  3QaPy1KgI7nu9FJEQUgn6h                               WILDFLOWER
# 11  6eLQXa6uk2EW8drsiKbABZ                                TU SANCHO
# 12  2yWlGEgEfPot0lv3OAjuG3  Just Keep Watching (From F1® The Movie)
# ...

# %%
# save the 2025-06-11 dataset to data/spotify_2025_06_11.csv in top50_dataset_2025.csv
df.to_csv('data/spotify_2025_06_11.csv', index=False)

# %%
# extract number of unique countries from col "country"
df['country'].nunique()
# Out:
# 71

# %%
# extract number of songs per country 
df['country'].value_counts()
# Out:
# country
# ZA    50
# VN    50
# VE    50
# UY    50
# US    50
#       ..
# BE    50
# AU    50
# AT    50
# AR    50
# AE    50
# Name: count, Length: 71, dtype: int64
